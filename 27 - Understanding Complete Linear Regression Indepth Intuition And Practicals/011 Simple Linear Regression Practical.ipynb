# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline
data={'w':[45,58,48,60,70,78,80,90,95,78,82],
    'h':[120,135,123,145,160,162,163,175,182,170,176]}
df=pd.DataFrame(data)
x=df[['w']]
y=df['h']

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.25,random_state=42)
x_train.shape
y_train.shape
# Out:
# (8,)

# %%
# standardization
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
x_train=scaler.fit_transform(x_train)
x_test=scaler.transform(x_test)
x_test
# Out:
# array([[ 0.3298844 ],
#        [-1.79424932],
#        [ 0.3298844 ]])

# %% [markdown]
# <!-- apply simple linear regression -->

# %%
from sklearn.linear_model import LinearRegression
regression=LinearRegression()
regression.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
print("coeef or slope",regression.coef_)
print("coeef or slope",regression.intercept_)
# Out:
# coeef or slope [19.28113995]
# coeef or slope 157.375

# %%
plt.scatter(x_train,y_train)
plt.scatter(x_train,regression.predict(x_train),color='red')
plt.plot(x_train,regression.predict(x_train))
plt.show()
